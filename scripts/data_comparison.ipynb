# %%
import mne
import matplotlib.pyplot as plt
import numpy as np

# %%
SUBJECT = "T001"

montage = mne.channels.make_standard_montage("standard_1020")

# %%
# load raw EEG data
raw_eeg_file = (
    f"../../ped_neuro_eeg_data/bids/sub-{SUBJECT}/eeg/sub-{SUBJECT}_task-rest_eeg.vhdr"
)
raw = mne.io.read_raw_brainvision(raw_eeg_file, preload=True)
raw.pick(picks="eeg")

raw.set_montage(montage, match_case=False, on_missing="ignore")
# Out:
# Extracting parameters from ../../ped_neuro_eeg_data/bids/sub-T001/eeg/sub-T001_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 308339  =      0.000 ...  1233.356 secs...
# <RawBrainVision | sub-T001_task-rest_eeg.eeg, 27 x 308340 (1233.4 s), ~63.6 MiB, data loaded>

# %%
# load cleaned EEG data
cleaned_eeg_file = f"../../ped_neuro_eeg_data/bids/sub-{SUBJECT}/eeg/sub-{SUBJECT}_task-rest_cleaned_eeg.fif"
cleaned = mne.io.read_raw_fif(cleaned_eeg_file, preload=True)
cleaned.set_montage(montage, match_case=False, on_missing="ignore")
# Out:
# Opening raw data file ../../ped_neuro_eeg_data/bids/sub-T001/eeg/sub-T001_task-rest_cleaned_eeg.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 21)  idle
#     Range : 79170 ... 229170 =    316.680 ...   916.680 secs
# Ready.
# Reading 0 ... 150000  =      0.000 ...   600.000 secs...
# <Raw | sub-T001_task-rest_cleaned_eeg.fif, 19 x 150001 (600.0 s), ~21.8 MiB, data loaded>

# %%
# raw data plots
raw.plot(scalings={"eeg": 10e-2})
raw.compute_psd(fmax=50).plot()
# Out:
# <MNELineFigure size 1000x350 with 2 Axes>
# <MNEBrowseFigure size 2056x800 with 4 Axes>
# Effective window size : 8.192 (s)
# Plotting power spectral density (dB=True).
# c:\Users\demsa\miniconda3\Lib\site-packages\mne\viz\utils.py:158: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   (fig or plt).show(**kwargs)
# <MNELineFigure size 1000x350 with 2 Axes>

# %%
# cleaned data plots
cleaned.plot(scalings={"eeg": 10e-3})
cleaned.compute_psd(fmax=50).plot()
# Out:
# <MNELineFigure size 1000x350 with 2 Axes>
# <MNEBrowseFigure size 2056x800 with 5 Axes>
# Effective window size : 8.192 (s)
# Plotting power spectral density (dB=True).
# c:\Users\demsa\miniconda3\Lib\site-packages\mne\viz\utils.py:158: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   (fig or plt).show(**kwargs)
# <MNELineFigure size 1000x350 with 2 Axes>
